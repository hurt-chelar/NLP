# %%
sentences  = [ "Three years later the coffin was full of jello", 
                "There is not time to fill the coffin of jello",
                "time and tide awaits for no one",
                "there is no time remaining",
                "Three years later the coffin was full of time"]



model_name = 'bert-base-nli-mean-tokens'
from sentence_transformers import SentenceTransformer
model =  SentenceTransformer(model_name)
sentence_vectors = model.encode(sentences)

from sklearn.metrics.pairwise import cosine_similarity

# %%
ans = cosine_similarity(
    [sentence_vectors[0]],sentence_vectors[1:]
)
type(ans)
# Out:
# numpy.ndarray

# %%
# Out:
# 0.5735097

# %%
import matplotlib.pyplot as ply
# %matplotlib inline

# %%
x = list(range(0,10))
y = list(range(-10,0))

# %%
a = [ans[0][0]*100,ans[0][1]*100,ans[0][2]*100,ans[0][3]*100] 
b = [sentences[1],sentences[2],sentences[3],sentences[4]]

# %%
ply.plot(b,a)
ply.xticks(rotation = 90)
ply.title(sentences[0])
# Out:
# Text(0.5, 1.0, 'Three years later the coffin was full of jello')
